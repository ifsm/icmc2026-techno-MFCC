# %%
import os
import shutil
import csv

subgenre = r'C:\Users\t_ziemer\Downloads\trance.csv'  # csv-file containing file names
folder2 = r'C:\Users\t_ziemer\Desktop\techno-mfccbpm\germany'  # Path to source files
folder3 = r'C:\Users\t_ziemer\Desktop\techno-mfccbpm-g\trance'  # target folder path

# Step 1: Import the subgenre CSV file
with open(subgenre, newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    headers = next(reader)  # Skip header row
    filenames = [row[0] for row in reader]  # Collect filenames from the first column

# Ensure the target directory exists
os.makedirs(folder3, exist_ok=True)

# Step 2 & 3: Check for each filename and copy if exists, else print filename
for filename in filenames:
    source_path = os.path.join(folder2, filename)
    destination_path = os.path.join(folder3, filename)

    if os.path.isfile(source_path):
        shutil.copy2(source_path, destination_path)
    else:
        print(f"File not found: {filename}")
# Out:
# File not found: DJ Hooligan - It's A Dreamsong (Remix) (1992).opus.csv
# File not found: Paragliders - Paraglide (Humate Remix) (1994).mp3.csv
# File not found: Solar Eclipse - Thirsty Float (1994).m4a.csv
# File not found: Taucher - Atlantis (The Realmix) (1993).m4a.csv
# File not found: The Ambush - Aton (Be-Zet Mix)  (1994).opus.csv

# %%
import os
import shutil

subgenre = r'C:\Users\t_ziemer\Downloads\trance.csv'  # csv-file containing file names
folder2 = r'C:\Users\t_ziemer\Desktop\techno-mfcc\germany'  # Path to source files
folder3 = r'C:\Users\t_ziemer\Desktop\techno-mfcc-g\trance'  # target folder path

# Listen erstellen
csvlist = []
for root, dirs, files in os.walk(folder1):
    for file in files:
        if file.endswith('.csv'):
            csvlist.append(file[:-4])  # Nur der Dateiname ohne Endung

audiolist = []
for root, dirs, files in os.walk(folder2):
    for file in files:
        audiolist.append(file)  # gesamte Dateinamen

# Fehlende Einträge überprüfen
missinglist = []

for audio in audiolist:
    audio_name = audio  # Dateiname ohne Endung (hier wird angenommen, dass die Audiodateien ebenfalls eine Endung wie .mp3 oder .wav haben)
    if audio_name not in csvlist:  # Überprüfung ohne Endung
        missinglist.append(audio)

# Ausgabe der Listen
#print("CSV-Dateien:", csvlist)
#print("Audio-Dateien:", audiolist)
#print("Fehlende Audio-Dateien:", missinglist)

# %%
missinglist
# Out:
# ["Mr. Lee - I Can't Forget (Club) (1987).opus",
#  'Joint Venture - Love And Happiness (New York Club Mix) (1991).m4a',
#  "Fingers Inc - It's Over (Dub) (1986).opus",
#  'B.G. The Prince of Rap - Walk over the rainbow (1994).mp3',
#  'Inner City - Save the children (1992).mp3',
#  "Beatboxx Feat. Chazzie - Keep On Jumpin' (Egotrip Mix) (1991).m4a",
#  'Phutute Scope - Plastic (J.D. Mix) (1993).m4a',
#  'B.G. The Prince of Rap - Wanna be free (1994).mp3',
#  'B.G. The Prince of Rap - Giveme the music (Club devotion mix) (1991).mp3',
#  "Terrance Parker - Set Me Free (TP's Spiritual Freedom Dub Mix) (1994).m4a",
#  'Mr. Lee - Get Busy (Club Mix) (1989).m4a',
#  'Cybotron - Enter (1990).mp3',
#  'Photon Inc. Feat. Paula Brion - Generate Power (Instrumental) (1991).m4a',
#  "D'Bora - Love Desire (Club Mix) (152kbit_Opus).mp3",
#  'B.G. The Prince of Rap - Can we get enough (1994).mp3',
#  'Mr. Lee - I Like The Girls (1990).m4a',
# ...

# %%
if not os.path.exists(folder3):
    os.makedirs(folder3)

# Fehlende Audio-Dateien in den neuen Ordner kopieren
for missing_audio in missinglist:
    # Vollständiger Pfad der fehlenden Datei
    source_file = os.path.join(folder2, missing_audio)
    # Zielpfad, wo die Datei kopiert werden soll
    destination_file = os.path.join(folder3, missing_audio)
    # Datei kopieren
    shutil.copy2(source_file, destination_file)
